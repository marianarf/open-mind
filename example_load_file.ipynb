# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('sample/mindMonitor_2020-03-01--12-50-38.csv')

# %%
df = df.set_index(pd.DatetimeIndex(df['TimeStamp']))

# %%
df.pop('TimeStamp')
df.head(5)
# Out:
#                          Delta_TP9  Delta_AF7  Delta_AF8  Delta_TP10  \
# TimeStamp
# 2020-03-01 12:50:39.029        0.0        0.0        0.0         0.0
# 2020-03-01 12:50:40.029        0.0        0.0        0.0         0.0
# 2020-03-01 12:50:41.028        0.0        0.0        0.0         0.0
# 2020-03-01 12:50:42.029        0.0        0.0        0.0         0.0
# 2020-03-01 12:50:43.029        0.0        0.0        0.0         0.0
#
#                          Theta_TP9  Theta_AF7  Theta_AF8  Theta_TP10  \
# TimeStamp
# 2020-03-01 12:50:39.029        0.0        0.0        0.0         0.0
# 2020-03-01 12:50:40.029        0.0        0.0        0.0         0.0
# 2020-03-01 12:50:41.028        0.0        0.0        0.0         0.0
# 2020-03-01 12:50:42.029        0.0        0.0        0.0         0.0
# 2020-03-01 12:50:43.029        0.0        0.0        0.0         0.0
#
#                          Alpha_TP9  Alpha_AF7  ...    Gyro_X    Gyro_Y  \
# ...

# %%
df.groupby(df.index.to_period('Min'))['Theta_TP9'].apply(lambda x: np.mean(x)).plot()
